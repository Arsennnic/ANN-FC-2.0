# %%
import istab_pm as st

# %%
model_1010 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 1000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 500, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h1010")

# %%
model_20 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [20], batch_size = 1000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h20")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000499 / 0.000499) - 1.0 = 0.0000
#     Epoch 00200: MGL: (0.000278 / 0.000278) - 1.0 = 0.0000
#     Epoch 00300: MGL: (0.000180 / 0.000180) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.000136 / 0.000136) - 1.0 = 0.0000
#     Epoch 00500: MGL: (0.000118 / 0.000118) - 1.0 = 0.0000
#     Epoch 00600: MGL: (0.000103 / 0.000103) - 1.0 = 0.0000
#     Epoch 00700: MGL: (0.000091 / 0.000091) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.000084 / 0.000084) - 1.0 = 0.0000
#     Epoch 00900: MGL: (0.000077 / 0.000077) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.000073 / 0.000073) - 1.0 = 0.0000
#     Epoch 01100: MGL: (0.000067 / 0.000067) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.000067 / 0.000067) - 1.0 = 0.0000
#     Epoch 01300: MGL: (0.000065 / 0.000065) - 1.0 = 0.0000
# ...

# %%
model_40 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [40], batch_size = 1000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h40")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000427 / 0.000427) - 1.0 = 0.0000
#     Epoch 00200: MGL: (0.000219 / 0.000219) - 1.0 = 0.0000
#     Epoch 00300: MGL: (0.000156 / 0.000156) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.000119 / 0.000119) - 1.0 = 0.0000
#     Epoch 00500: MGL: (0.000099 / 0.000099) - 1.0 = 0.0000
#     Epoch 00600: MGL: (0.000088 / 0.000088) - 1.0 = 0.0000
#     Epoch 00700: MGL: (0.000077 / 0.000077) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.000074 / 0.000074) - 1.0 = 0.0000
#     Epoch 00900: MGL: (0.000065 / 0.000065) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.000062 / 0.000062) - 1.0 = 0.0000
#     Epoch 01100: MGL: (0.000058 / 0.000058) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.000057 / 0.000057) - 1.0 = 0.0000
#     Epoch 01300: MGL: (0.000052 / 0.000052) - 1.0 = 0.0000
# ...

# %%
model_1010.store_model('stab-1010')
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P10')
# Out:
# Correct: 5062
# Wrong: 89
# Uncertain: 0
# Accuracy: 9.827218e-01

# %%
model_20.store_model('stab-20')
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_20.plot()
# Out:
# Correct: 5055
# Wrong: 96
# Uncertain: 0
# Accuracy: 9.813628e-01

# %%
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
# Out:
# Correct: 5123
# Wrong: 28
# Uncertain: 0
# Accuracy: 9.945642e-01
# Correct: 5140
# Wrong: 11
# Uncertain: 0
# Accuracy: 9.978645e-01
# Correct: 5139
# Wrong: 12
# Uncertain: 0
# Accuracy: 9.976704e-01
# Correct: 5147
# Wrong: 4
# Uncertain: 0
# Accuracy: 9.992235e-01
# Correct: 5151
# Wrong: 0
# Uncertain: 0
# Accuracy: 1.000000e+00
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]),
#   array([210., 210., 210., ..., 210., 210., 210.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)]}

# %%
model_40.store_model('stab-40')
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_40.plot()
# Out:
# Correct: 5059
# Wrong: 92
# Uncertain: 0
# Accuracy: 9.821394e-01

# %%
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
# Out:
# Correct: 5141
# Wrong: 10
# Uncertain: 0
# Accuracy: 9.980586e-01
# Correct: 5134
# Wrong: 17
# Uncertain: 0
# Accuracy: 9.966997e-01
# Correct: 5143
# Wrong: 8
# Uncertain: 0
# Accuracy: 9.984469e-01
# Correct: 5150
# Wrong: 1
# Uncertain: 0
# Accuracy: 9.998059e-01
# Correct: 5150
# Wrong: 1
# Uncertain: 0
# Accuracy: 9.998059e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]),
#   array([210., 210., 210., ..., 210., 210., 210.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.63, 0.08, 0.29]]), array([210.])]}

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 1.5)
model_1010.plot()
# Out:
# Correct: 4959
# Wrong: 58
# Uncertain: 134
# Accuracy: 9.887401e-01
# Correct: 4696
# Wrong: 35
# Uncertain: 420
# Accuracy: 9.932052e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P50')
# Out:
# Correct: 5139
# Wrong: 12
# Uncertain: 0
# Accuracy: 9.976704e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 1.5)
model_1010.plot()
# Out:
# Correct: 5102
# Wrong: 1
# Uncertain: 48
# Accuracy: 9.998059e-01
# Correct: 5057
# Wrong: 0
# Uncertain: 94
# Accuracy: 1.000000e+00

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P90')
# Out:
# Correct: 5139
# Wrong: 12
# Uncertain: 0
# Accuracy: 9.976704e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 1.5)
model_1010.plot()
# Out:
# Correct: 5110
# Wrong: 3
# Uncertain: 38
# Accuracy: 9.994176e-01
# Correct: 5073
# Wrong: 2
# Uncertain: 76
# Accuracy: 9.996117e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P130')
# Out:
# Correct: 5141
# Wrong: 10
# Uncertain: 0
# Accuracy: 9.980586e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 1.5)
model_1010.plot()
# Out:
# Correct: 5127
# Wrong: 6
# Uncertain: 18
# Accuracy: 9.988352e-01
# Correct: 5094
# Wrong: 1
# Uncertain: 56
# Accuracy: 9.998059e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P170')
# Out:
# Correct: 5145
# Wrong: 6
# Uncertain: 0
# Accuracy: 9.988352e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 1.5)
model_1010.plot()
# Out:
# Correct: 5138
# Wrong: 2
# Uncertain: 11
# Accuracy: 9.996117e-01
# Correct: 5115
# Wrong: 0
# Uncertain: 36
# Accuracy: 1.000000e+00

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
model_1010.plot('stability-T450-P210')
# Out:
# Correct: 5148
# Wrong: 3
# Uncertain: 0
# Accuracy: 9.994176e-01

# %%
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 0.5)
model_1010.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 1.5)

model_1010.plot()
# Out:
# Correct: 5140
# Wrong: 0
# Uncertain: 11
# Accuracy: 1.000000e+00
# Correct: 5128
# Wrong: 0
# Uncertain: 23
# Accuracy: 1.000000e+00

# %%
geo003_1010 = st.train("improved-STAB-data/geo003-train-simplex-PS-PM.csv",
                 "improved-STAB-data/geo003-test-simplex-PS-PM.csv",
                 #validation_data = "improved-STAB-data/geo003-val-simplex-PS-PM.csv",
                 validation_split = 0.05,
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 1000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 500, epoch = 3000, 
                       trans = None, train_number = 5, 
                 plot = True, plot_name = "geo003-ST-h1010")
# Out:
# *** Number of training examples: 39596
# *** Number of testing examples: 2707
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000327 / 0.000327) - 1.0 = 0.000000
#     Epoch 00200: MGL: (0.000193 / 0.000193) - 1.0 = 0.000000
#     Epoch 00300: MGL: (0.000160 / 0.000160) - 1.0 = 0.000000
#     Epoch 00400: MGL: (0.000128 / 0.000128) - 1.0 = 0.000000
#     Epoch 00500: MGL: (0.000123 / 0.000123) - 1.0 = 0.000000
#     Epoch 00600: MGL: (0.000099 / 0.000099) - 1.0 = 0.000000
#     Epoch 00700: MGL: (0.000098 / 0.000098) - 1.0 = 0.000000
#     Epoch 00800: MGL: (0.000092 / 0.000092) - 1.0 = 0.000000
#     Epoch 00900: MGL: (0.000072 / 0.000072) - 1.0 = 0.000000
#     Epoch 01000: MGL: (0.000059 / 0.000059) - 1.0 = 0.000000
#     Epoch 01100: MGL: (0.000056 / 0.000056) - 1.0 = 0.000000
#     Epoch 01200: MGL: (0.000053 / 0.000053) - 1.0 = 0.000000
#     Epoch 01300: MGL: (0.000048 / 0.000048) - 1.0 = 0.000000
# ...

# %%
geo003_1010.store_model('geo003-stab')

# %%
spe3_1010 = st.train("improved-STAB-data/spe3-train-PS-PM.csv",
                 "improved-STAB-data/spe3-test-no-adv-simplex-PS-PM.csv",
                 #validation_data = "improved-STAB-data/spe3-test-no-adv-simplex-PS-PM.csv",
                 validation_split = 0.01,
                     filt_lower = 100.0,
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 5000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 500, epoch = 3000, 
                       trans = None, train_number = 5, 
                 plot = True, plot_name = "spe3-ST-h1010")
# Out:
# *** Number of training examples: 244464
# *** Number of testing examples: 1288
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000495 / 0.000495) - 1.0 = 0.000000
#     Epoch 00200: MGL: (0.000126 / 0.000126) - 1.0 = 0.000000
#     Epoch 00300: MGL: (0.000041 / 0.000041) - 1.0 = 0.000000
#     Epoch 00400: MGL: (0.000027 / 0.000027) - 1.0 = 0.000000
#     Epoch 00500: MGL: (0.000028 / 0.000027) - 1.0 = 0.051567
#     Epoch 00600: MGL: (0.000027 / 0.000027) - 1.0 = 0.011191
#     Epoch 00700: MGL: (0.000024 / 0.000024) - 1.0 = 0.000000
#     Epoch 00800: MGL: (0.000020 / 0.000020) - 1.0 = 0.000000
#     Epoch 00900: MGL: (0.000018 / 0.000018) - 1.0 = 0.000000
#     Epoch 01000: MGL: (0.000018 / 0.000018) - 1.0 = 0.000000
#     Epoch 01100: MGL: (0.000017 / 0.000017) - 1.0 = 0.000000
#     Epoch 01200: MGL: (0.000017 / 0.000017) - 1.0 = 0.001025
#     Epoch 01300: MGL: (0.000019 / 0.000017) - 1.0 = 0.080947
# ...

# %%
spe3_1010_2 = st.train("improved-STAB-data/spe3-train-PS-PM.csv",
                 "improved-STAB-data/spe3-train-PS-PM.csv",
                 #validation_data = "improved-STAB-data/spe3-test-no-adv-simplex-PS-PM.csv",
                 validation_split = 0.001,
                     filt_lower = 100.0,
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 3000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 1500, epoch = 3000, 
                       trans = None, train_number = 5, 
                 plot = True, plot_name = "spe3-ST-h1010")
# Out:
# *** Number of training examples: 244464
# *** Number of testing examples: 244464
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000117 / 0.000117) - 1.0 = 0.000000
#     Epoch 00200: MGL: (0.000056 / 0.000056) - 1.0 = 0.000000
#     Epoch 00300: MGL: (0.000032 / 0.000032) - 1.0 = 0.000000
#     Epoch 00400: MGL: (0.000031 / 0.000031) - 1.0 = 0.000000
#     Epoch 00500: MGL: (0.000029 / 0.000029) - 1.0 = 0.000000
#     Epoch 00600: MGL: (0.000028 / 0.000028) - 1.0 = 0.000000
#     Epoch 00700: MGL: (0.000030 / 0.000028) - 1.0 = 0.063872
#     Epoch 00800: MGL: (0.000025 / 0.000025) - 1.0 = 0.000000
#     Epoch 00900: MGL: (0.000025 / 0.000025) - 1.0 = 0.012857
#     Epoch 01000: MGL: (0.000024 / 0.000024) - 1.0 = 0.000000
#     Epoch 01100: MGL: (0.000025 / 0.000024) - 1.0 = 0.021869
#     Epoch 01200: MGL: (0.000026 / 0.000024) - 1.0 = 0.068855
#     Epoch 01300: MGL: (0.000024 / 0.000024) - 1.0 = 0.003292
# ...

# %%
spe3_1515_2 = st.train("improved-STAB-data/spe3-train-PS-PM.csv",
                 "improved-STAB-data/spe3-train-PS-PM.csv",
                 #validation_data = "improved-STAB-data/spe3-test-no-adv-simplex-PS-PM.csv",
                 validation_split = 0.001,
                     filt_lower = 100.0,
                 hidden_layer = 2, hidden_cells = [15, 15], batch_size = 3000, 
                 GL = 0.05, GL_epoch_strip = 100, min_epoch = 1500, epoch = 3000, 
                       trans = None, train_number = 5, 
                 plot = True, plot_name = "spe3-ST-h1515")
# Out:
# *** Number of training examples: 244464
# *** Number of testing examples: 244464
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00100: MGL: (0.000201 / 0.000201) - 1.0 = 0.000000
#     Epoch 00200: MGL: (0.000045 / 0.000045) - 1.0 = 0.000000
#     Epoch 00300: MGL: (0.000026 / 0.000026) - 1.0 = 0.000000
#     Epoch 00400: MGL: (0.000022 / 0.000022) - 1.0 = 0.000000
#     Epoch 00500: MGL: (0.000020 / 0.000020) - 1.0 = 0.000000
#     Epoch 00600: MGL: (0.000021 / 0.000020) - 1.0 = 0.032849
#     Epoch 00700: MGL: (0.000021 / 0.000020) - 1.0 = 0.033478
#     Epoch 00800: MGL: (0.000019 / 0.000019) - 1.0 = 0.000000
#     Epoch 00900: MGL: (0.000016 / 0.000016) - 1.0 = 0.000000
#     Epoch 01000: MGL: (0.000014 / 0.000014) - 1.0 = 0.000000
#     Epoch 01100: MGL: (0.000016 / 0.000014) - 1.0 = 0.196238
#     Epoch 01200: MGL: (0.000012 / 0.000012) - 1.0 = 0.000000
#     Epoch 01300: MGL: (0.000012 / 0.000012) - 1.0 = 0.000000
# ...

# %%
spe3_1515_2.store_model('spe3-stab-1515')

# %%
spe3_1010.store_model('spe3-stab')

# %%
spe3_1010_2.store_model('spe3-stab-2')
