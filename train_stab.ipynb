# %%
import istab_pm as st

# %%
model_1010 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 500, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h1010")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00200: MGL: (0.0073 / 0.0072) - 1.0 = 0.0205
#     Epoch 00400: MGL: (0.0020 / 0.0020) - 1.0 = 0.0190
#     Epoch 00600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0070
#     Epoch 00800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0005 / 0.0005) - 1.0 = 0.0093
#     Epoch 01200: MGL: (0.0005 / 0.0004) - 1.0 = 0.0682
#     Epoch 01400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0263
#     Epoch 01600: MGL: (0.0003 / 0.0003) - 1.0 = 0.0079
#     Epoch 01800: MGL: (0.0003 / 0.0003) - 1.0 = 0.1269
#     Earlystopping! Best Performance epoch 1776
#     Training Loss: 0.00024, MAE: 0.01085
# ============ TRAINING PROCESS: 2 ============
#     Epoch 00200: MGL: (0.0119 / 0.0116) - 1.0 = 0.0206
#     Epoch 00400: MGL: (0.0024 / 0.0024) - 1.0 = 0.0182
# ...

# %%
model_20 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [20], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h20")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00200: MGL: (0.0080 / 0.0080) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.0039 / 0.0039) - 1.0 = 0.0000
#     Epoch 00600: MGL: (0.0025 / 0.0025) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.0018 / 0.0018) - 1.0 = 0.0084
#     Epoch 01000: MGL: (0.0014 / 0.0013) - 1.0 = 0.0049
#     Epoch 01200: MGL: (0.0011 / 0.0011) - 1.0 = 0.0017
#     Epoch 01400: MGL: (0.0009 / 0.0009) - 1.0 = 0.0034
#     Epoch 01600: MGL: (0.0008 / 0.0008) - 1.0 = 0.0000
#     Epoch 01800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0000
#     Epoch 02000: MGL: (0.0006 / 0.0006) - 1.0 = 0.0000
#     Epoch 02200: MGL: (0.0006 / 0.0006) - 1.0 = 0.0106
#     Epoch 02400: MGL: (0.0006 / 0.0006) - 1.0 = 0.0057
#     Epoch 02600: MGL: (0.0005 / 0.0005) - 1.0 = 0.0065
#     Epoch 02800: MGL: (0.0005 / 0.0005) - 1.0 = 0.0098
# ...

# %%
model_40 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [40], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h40")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00200: MGL: (0.0080 / 0.0079) - 1.0 = 0.0078
#     Epoch 00400: MGL: (0.0040 / 0.0039) - 1.0 = 0.0182
#     Epoch 00600: MGL: (0.0024 / 0.0024) - 1.0 = 0.0041
#     Epoch 00800: MGL: (0.0017 / 0.0017) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0013 / 0.0013) - 1.0 = 0.0001
#     Epoch 01200: MGL: (0.0011 / 0.0011) - 1.0 = 0.0000
#     Epoch 01400: MGL: (0.0009 / 0.0009) - 1.0 = 0.0000
#     Epoch 01600: MGL: (0.0008 / 0.0008) - 1.0 = 0.0000
#     Epoch 01800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0033
#     Epoch 02000: MGL: (0.0006 / 0.0006) - 1.0 = 0.0000
#     Epoch 02200: MGL: (0.0006 / 0.0006) - 1.0 = 0.0035
#     Epoch 02400: MGL: (0.0006 / 0.0005) - 1.0 = 0.0193
#     Epoch 02600: MGL: (0.0005 / 0.0005) - 1.0 = 0.0196
#     Epoch 02800: MGL: (0.0005 / 0.0005) - 1.0 = 0.0013
# ...

# %%
model = st.ANN_STAB(file_name = 'stab-1010', level = 3)

# %%
model.store_model('stab-1010')
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model.plot('stability-T450-P10')
# Out:
# Correct: 5067
# Wrong: 84
# Uncertain: 0
# Accuracy: 9.836925e-01

# %%
model_10.store_model('stab-10')
model_10.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_10.plot()
# Out:
# Correct: 5049
# Wrong: 102
# Uncertain: 0
# Accuracy: 9.801980e-01

# %%
model_20.store_model('stab-20')
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_20.plot()
# Out:
# Correct: 5040
# Wrong: 111
# Uncertain: 0
# Accuracy: 9.784508e-01

# %%
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
# Out:
# Correct: 5135
# Wrong: 16
# Uncertain: 0
# Accuracy: 9.968938e-01
# Correct: 5110
# Wrong: 41
# Uncertain: 0
# Accuracy: 9.920404e-01
# Correct: 5123
# Wrong: 28
# Uncertain: 0
# Accuracy: 9.945642e-01
# Correct: 5144
# Wrong: 7
# Uncertain: 0
# Accuracy: 9.986410e-01
# Correct: 5141
# Wrong: 10
# Uncertain: 0
# Accuracy: 9.980586e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]),
#   array([210., 210., 210., ..., 210., 210., 210.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.62, 0.02, 0.36],
#          [0.62, 0.03, 0.35],
#          [0.63, 0.06, 0.31],
#          [0.63, 0.07, 0.3 ],
#          [0.64, 0.1 , 0.26],
#          [0.65, 0.12, 0.23],
#          [0.66, 0.14, 0.2 ],
#          [0.67, 0.15, 0.18],
#          [0.68, 0.16, 0.16],
# ...

# %%
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P20-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P30-simplex-STAB-PM.csv")
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P40-simplex-STAB-PM.csv")
# Out:
# Correct: 5117
# Wrong: 34
# Uncertain: 0
# Accuracy: 9.933993e-01
# Correct: 5108
# Wrong: 43
# Uncertain: 0
# Accuracy: 9.916521e-01
# Correct: 5134
# Wrong: 17
# Uncertain: 0
# Accuracy: 9.966997e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]), array([40., 40., 40., ..., 40., 40., 40.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.12, 0.88, 0.  ],
#          [0.13, 0.85, 0.02],
#          [0.13, 0.86, 0.01],
#          [0.13, 0.87, 0.  ],
#          [0.14, 0.24, 0.62],
#          [0.14, 0.25, 0.61],
#          [0.14, 0.26, 0.6 ],
#          [0.14, 0.27, 0.59],
#          [0.14, 0.28, 0.58],
#          [0.14, 0.29, 0.57],
#          [0.55, 0.45, 0.  ],
#          [0.62, 0.37, 0.01],
#          [0.69, 0.29, 0.02],
#          [0.77, 0.2 , 0.03],
# ...

# %%
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P20-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P30-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P40-simplex-STAB-PM.csv")
# Out:
# Correct: 5099
# Wrong: 52
# Uncertain: 0
# Accuracy: 9.899049e-01
# Correct: 5128
# Wrong: 23
# Uncertain: 0
# Accuracy: 9.955348e-01
# Correct: 5118
# Wrong: 33
# Uncertain: 0
# Accuracy: 9.935935e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]), array([40., 40., 40., ..., 40., 40., 40.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.13, 0.65, 0.22],
#          [0.13, 0.66, 0.21],
#          [0.13, 0.67, 0.2 ],
#          [0.13, 0.68, 0.19],
#          [0.13, 0.69, 0.18],
#          [0.13, 0.7 , 0.17],
#          [0.13, 0.71, 0.16],
#          [0.13, 0.72, 0.15],
#          [0.13, 0.73, 0.14],
#          [0.13, 0.74, 0.13],
#          [0.13, 0.75, 0.12],
#          [0.13, 0.76, 0.11],
#          [0.13, 0.77, 0.1 ],
#          [0.13, 0.78, 0.09],
# ...

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P20-simplex-STAB-PM.csv")
model.stab_test("improved-STAB-data/stability-simplex-T450-P30-simplex-STAB-PM.csv")
model.stab_test("improved-STAB-data/stability-simplex-T450-P40-simplex-STAB-PM.csv")
# Out:
# Correct: 5111
# Wrong: 40
# Uncertain: 0
# Accuracy: 9.922345e-01
# Correct: 5098
# Wrong: 53
# Uncertain: 0
# Accuracy: 9.897107e-01
# Correct: 5134
# Wrong: 17
# Uncertain: 0
# Accuracy: 9.966997e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]), array([40., 40., 40., ..., 40., 40., 40.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.14, 0.24, 0.62],
#          [0.14, 0.25, 0.61],
#          [0.14, 0.26, 0.6 ],
#          [0.14, 0.27, 0.59],
#          [0.14, 0.28, 0.58],
#          [0.14, 0.29, 0.57],
#          [0.14, 0.3 , 0.56],
#          [0.14, 0.31, 0.55],
#          [0.14, 0.32, 0.54],
#          [0.14, 0.33, 0.53],
#          [0.14, 0.34, 0.52],
#          [0.14, 0.35, 0.51],
#          [0.14, 0.79, 0.07],
#          [0.14, 0.8 , 0.06],
# ...

# %%
model_40.store_model('stab-40')
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_40.plot()
# Out:
# Correct: 5040
# Wrong: 111
# Uncertain: 0
# Accuracy: 9.784508e-01

# %%
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
# Out:
# Correct: 5126
# Wrong: 25
# Uncertain: 0
# Accuracy: 9.951466e-01
# Correct: 5118
# Wrong: 33
# Uncertain: 0
# Accuracy: 9.935935e-01
# Correct: 5130
# Wrong: 21
# Uncertain: 0
# Accuracy: 9.959231e-01
# Correct: 5132
# Wrong: 19
# Uncertain: 0
# Accuracy: 9.963114e-01
# Correct: 5141
# Wrong: 10
# Uncertain: 0
# Accuracy: 9.980586e-01
# {'correct': [array([[0.  , 0.  , 1.  ],
#          [0.  , 0.01, 0.99],
#          [0.  , 0.02, 0.98],
#          ...,
#          [0.99, 0.  , 0.01],
#          [0.99, 0.01, 0.  ],
#          [1.  , 0.  , 0.  ]]),
#   array([210., 210., 210., ..., 210., 210., 210.])],
#  'unknown': [array([], shape=(0, 3), dtype=float64), array([], dtype=float64)],
#  'wrong': [array([[0.61, 0.  , 0.39],
#          [0.63, 0.07, 0.3 ],
#          [0.64, 0.1 , 0.26],
#          [0.65, 0.12, 0.23],
#          [0.66, 0.14, 0.2 ],
#          [0.67, 0.15, 0.18],
#          [0.68, 0.16, 0.16],
#          [0.75, 0.16, 0.09],
#          [0.81, 0.12, 0.07],
# ...

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 4984
# Wrong: 26
# Uncertain: 141
# Accuracy: 9.949524e-01
# Correct: 4730
# Wrong: 3
# Uncertain: 418
# Accuracy: 9.994176e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model.plot('stability-T450-P50')
# Out:
# Correct: 5123
# Wrong: 28
# Uncertain: 0
# Accuracy: 9.945642e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5097
# Wrong: 19
# Uncertain: 35
# Accuracy: 9.963114e-01
# Correct: 5047
# Wrong: 4
# Uncertain: 100
# Accuracy: 9.992235e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model.plot('stability-T450-P90')
# Out:
# Correct: 5118
# Wrong: 33
# Uncertain: 0
# Accuracy: 9.935935e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5105
# Wrong: 21
# Uncertain: 25
# Accuracy: 9.959231e-01
# Correct: 5064
# Wrong: 15
# Uncertain: 72
# Accuracy: 9.970879e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model.plot('stability-T450-P130')
# Out:
# Correct: 5131
# Wrong: 20
# Uncertain: 0
# Accuracy: 9.961173e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5120
# Wrong: 14
# Uncertain: 17
# Accuracy: 9.972821e-01
# Correct: 5088
# Wrong: 6
# Uncertain: 57
# Accuracy: 9.988352e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model.plot('stability-T450-P170')
# Out:
# Correct: 5134
# Wrong: 17
# Uncertain: 0
# Accuracy: 9.966997e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5131
# Wrong: 8
# Uncertain: 12
# Accuracy: 9.984469e-01
# Correct: 5114
# Wrong: 1
# Uncertain: 36
# Accuracy: 9.998059e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
model.plot('stability-T450-P210')
# Out:
# Correct: 5140
# Wrong: 11
# Uncertain: 0
# Accuracy: 9.978645e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 1.5)

model.plot()
# Out:
# Correct: 5136
# Wrong: 7
# Uncertain: 8
# Accuracy: 9.986410e-01
# Correct: 5127
# Wrong: 2
# Uncertain: 22
# Accuracy: 9.996117e-01

# %%
model_10.store_model('stab-10')
model_10.stab_test("improved-STAB-data/stability-simplex-T450-simplex-STAB-PM.csv")
model_10.plot()
# Out:
# Correct: 5048
# Wrong: 103
# Uncertain: 0
# Accuracy: 9.800039e-01

# %%
model_20.store_model('stab-20')
model_20.stab_test("improved-STAB-data/stability-simplex-T450-simplex-STAB-PM.csv")
model_20.plot()
# Out:
# Correct: 5060
# Wrong: 91
# Uncertain: 0
# Accuracy: 9.823335e-01
