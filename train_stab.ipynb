# %%
import istab_pm as st

# %%
model = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 2, hidden_cells = [10, 10], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 500, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h1010")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 733
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00200: MGL: (0.0115 / 0.0114) - 1.0 = 0.0138
#     Epoch 00400: MGL: (0.0022 / 0.0022) - 1.0 = 0.0000
#     Epoch 00600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0476
#     Epoch 01000: MGL: (0.0006 / 0.0005) - 1.0 = 0.0188
#     Epoch 01200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0145
#     Epoch 01400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0496
#     Epoch 01600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0252
#     Epoch 01800: MGL: (0.0003 / 0.0003) - 1.0 = 0.0000
#     Epoch 02000: MGL: (0.0003 / 0.0003) - 1.0 = 0.1023
#     Earlystopping! Best Performance epoch 1998
#     Training Loss: 0.00024, MAE: 0.01083
# ============ TRAINING PROCESS: 2 ============
#     Epoch 00200: MGL: (0.0089 / 0.0088) - 1.0 = 0.0096
#     Epoch 00400: MGL: (0.0022 / 0.0021) - 1.0 = 0.0305
#     Epoch 00600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0085
#     Epoch 01000: MGL: (0.0006 / 0.0005) - 1.0 = 0.0119
#     Epoch 01200: MGL: (0.0005 / 0.0004) - 1.0 = 0.0268
#     Epoch 01400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0268
#     Epoch 01600: MGL: (0.0003 / 0.0003) - 1.0 = 0.0026
#     Epoch 01800: MGL: (0.0003 / 0.0003) - 1.0 = 0.0239
#     Epoch 02000: MGL: (0.0003 / 0.0002) - 1.0 = 0.0665
#     Epoch 02200: MGL: (0.0002 / 0.0002) - 1.0 = 0.0708
#     Epoch 02400: MGL: (0.0002 / 0.0002) - 1.0 = 0.0834
#     Epoch 02600: MGL: (0.0002 / 0.0002) - 1.0 = 0.0000
#     Epoch 02800: MGL: (0.0002 / 0.0002) - 1.0 = 0.0401
#     Epoch 03000: MGL: (0.0001 / 0.0001) - 1.0 = 0.0482
#     Epoch 03200: MGL: (0.0001 / 0.0001) - 1.0 = 0.0660
#     Epoch 03400: MGL: (0.0001 / 0.0001) - 1.0 = 0.0545
#     Epoch 03600: MGL: (0.0001 / 0.0001) - 1.0 = 0.0618
#     Epoch 03800: MGL: (0.0001 / 0.0001) - 1.0 = 0.1250
#     Earlystopping! Best Performance epoch 3703
#     Training Loss: 0.00010, MAE: 0.00586
# ============ TRAINING PROCESS: 3 ============
#     Epoch 00200: MGL: (0.0068 / 0.0068) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.0020 / 0.0019) - 1.0 = 0.0216
#     Epoch 00600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0043
#     Epoch 00800: MGL: (0.0008 / 0.0008) - 1.0 = 0.0168
#     Epoch 01000: MGL: (0.0006 / 0.0006) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0184
#     Epoch 01400: MGL: (0.0005 / 0.0005) - 1.0 = 0.0136
#     Epoch 01600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0045
#     Epoch 01800: MGL: (0.0004 / 0.0004) - 1.0 = 0.0598
#     Epoch 02000: MGL: (0.0004 / 0.0003) - 1.0 = 0.0766
#     Epoch 02200: MGL: (0.0003 / 0.0003) - 1.0 = 0.0236
#     Epoch 02400: MGL: (0.0003 / 0.0003) - 1.0 = 0.0668
#     Epoch 02600: MGL: (0.0003 / 0.0003) - 1.0 = 0.1310
#     Earlystopping! Best Performance epoch 2588
#     Training Loss: 0.00021, MAE: 0.01020
# ============ TRAINING PROCESS: 4 ============
#     Epoch 00200: MGL: (0.0078 / 0.0077) - 1.0 = 0.0144
#     Epoch 00400: MGL: (0.0020 / 0.0019) - 1.0 = 0.0338
#     Epoch 00600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0001
#     Epoch 00800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0125
#     Epoch 01000: MGL: (0.0006 / 0.0006) - 1.0 = 0.0727
#     Epoch 01200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0243
#     Epoch 01400: MGL: (0.0005 / 0.0004) - 1.0 = 0.1055
#     Earlystopping! Best Performance epoch 1394
#     Training Loss: 0.00034, MAE: 0.01361
# ============ TRAINING PROCESS: 5 ============
#     Epoch 00200: MGL: (0.0064 / 0.0064) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.0018 / 0.0017) - 1.0 = 0.0221
#     Epoch 00600: MGL: (0.0009 / 0.0009) - 1.0 = 0.0041
#     Epoch 00800: MGL: (0.0007 / 0.0007) - 1.0 = 0.0044
#     Epoch 01000: MGL: (0.0006 / 0.0006) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0059
#     Epoch 01400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0000
#     Epoch 01600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0570
#     Epoch 01800: MGL: (0.0004 / 0.0003) - 1.0 = 0.0262
#     Epoch 02000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0354
#     Epoch 02200: MGL: (0.0003 / 0.0003) - 1.0 = 0.0399
#     Epoch 02400: MGL: (0.0003 / 0.0003) - 1.0 = 0.0390
#     Epoch 02600: MGL: (0.0002 / 0.0002) - 1.0 = 0.0124
#     Epoch 02800: MGL: (0.0002 / 0.0002) - 1.0 = 0.0114
#     Epoch 03000: MGL: (0.0002 / 0.0002) - 1.0 = 0.0656
#     Epoch 03200: MGL: (0.0002 / 0.0002) - 1.0 = 0.0745
#     Epoch 03400: MGL: (0.0001 / 0.0001) - 1.0 = 0.0130
#     Epoch 03600: MGL: (0.0001 / 0.0001) - 1.0 = 0.0813
#     Epoch 03800: MGL: (0.0001 / 0.0001) - 1.0 = 0.0163
#     Epoch 04000: MGL: (0.0001 / 0.0001) - 1.0 = 0.1509
#     Earlystopping! Best Performance epoch 3951
#     Training Loss: 0.00008, MAE: 0.00566
# Time cost: 408.798283 seconds

# %%
model_55 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 2, hidden_cells = [5, 5], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 500, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h55")

# %%
model_10 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [10], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h10")
# Out:
# *** Number of training examples: 9870
# *** Number of testing examples: 1439
# *** Number of validation examples: 1244
# *** Training begins ...
# ============ TRAINING PROCESS: 1 ============
#     Epoch 00200: MGL: (0.0078 / 0.0078) - 1.0 = 0.0000
#     Epoch 00400: MGL: (0.0045 / 0.0043) - 1.0 = 0.0439
#     Epoch 00600: MGL: (0.0029 / 0.0028) - 1.0 = 0.0166
#     Epoch 00800: MGL: (0.0021 / 0.0021) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0017 / 0.0016) - 1.0 = 0.0017
#     Epoch 01200: MGL: (0.0013 / 0.0013) - 1.0 = 0.0000
#     Epoch 01400: MGL: (0.0011 / 0.0011) - 1.0 = 0.0000
#     Epoch 01600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0000
#     Epoch 01800: MGL: (0.0009 / 0.0009) - 1.0 = 0.0021
#     Epoch 02000: MGL: (0.0008 / 0.0008) - 1.0 = 0.0016
#     Epoch 02200: MGL: (0.0007 / 0.0007) - 1.0 = 0.0143
#     Epoch 02400: MGL: (0.0006 / 0.0006) - 1.0 = 0.0078
#     Epoch 02600: MGL: (0.0006 / 0.0006) - 1.0 = 0.0139
#     Epoch 02800: MGL: (0.0005 / 0.0005) - 1.0 = 0.0184
#     Epoch 03000: MGL: (0.0005 / 0.0005) - 1.0 = 0.0091
#     Epoch 03200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0104
#     Epoch 03400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0156
#     Epoch 03600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0081
#     Epoch 03800: MGL: (0.0004 / 0.0004) - 1.0 = 0.0150
#     Epoch 04000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0313
#     Epoch 04200: MGL: (0.0003 / 0.0003) - 1.0 = 0.0275
#     Epoch 04400: MGL: (0.0003 / 0.0003) - 1.0 = 0.0106
#     Epoch 04600: MGL: (0.0003 / 0.0003) - 1.0 = 0.0502
#     Epoch 04800: MGL: (0.0003 / 0.0003) - 1.0 = 0.0100
#     Epoch 05000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0353
#     Training Loss: 0.00032, MAE: 0.00892
# ============ TRAINING PROCESS: 2 ============
#     Epoch 00200: MGL: (0.0076 / 0.0076) - 1.0 = 0.0032
#     Epoch 00400: MGL: (0.0040 / 0.0039) - 1.0 = 0.0026
#     Epoch 00600: MGL: (0.0026 / 0.0026) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.0019 / 0.0019) - 1.0 = 0.0013
#     Epoch 01000: MGL: (0.0016 / 0.0016) - 1.0 = 0.0053
#     Epoch 01200: MGL: (0.0013 / 0.0013) - 1.0 = 0.0028
#     Epoch 01400: MGL: (0.0011 / 0.0011) - 1.0 = 0.0031
#     Epoch 01600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0046
#     Epoch 01800: MGL: (0.0009 / 0.0009) - 1.0 = 0.0045
#     Epoch 02000: MGL: (0.0008 / 0.0008) - 1.0 = 0.0004
#     Epoch 02200: MGL: (0.0007 / 0.0007) - 1.0 = 0.0010
#     Epoch 02400: MGL: (0.0007 / 0.0007) - 1.0 = 0.0000
#     Epoch 02600: MGL: (0.0006 / 0.0006) - 1.0 = 0.0125
#     Epoch 02800: MGL: (0.0006 / 0.0006) - 1.0 = 0.0079
#     Epoch 03000: MGL: (0.0005 / 0.0005) - 1.0 = 0.0196
#     Epoch 03200: MGL: (0.0005 / 0.0005) - 1.0 = 0.0226
#     Epoch 03400: MGL: (0.0005 / 0.0005) - 1.0 = 0.0130
#     Epoch 03600: MGL: (0.0005 / 0.0004) - 1.0 = 0.0296
#     Epoch 03800: MGL: (0.0004 / 0.0004) - 1.0 = 0.0256
#     Epoch 04000: MGL: (0.0004 / 0.0004) - 1.0 = 0.0391
#     Epoch 04200: MGL: (0.0004 / 0.0004) - 1.0 = 0.0752
#     Epoch 04400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0000
#     Epoch 04600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0680
#     Epoch 04800: MGL: (0.0004 / 0.0004) - 1.0 = 0.1098
#     Earlystopping! Best Performance epoch 4716
#     Training Loss: 0.00044, MAE: 0.01242
# ============ TRAINING PROCESS: 3 ============
#     Epoch 00200: MGL: (0.0081 / 0.0080) - 1.0 = 0.0101
#     Epoch 00400: MGL: (0.0045 / 0.0044) - 1.0 = 0.0202
#     Epoch 00600: MGL: (0.0027 / 0.0027) - 1.0 = 0.0013
#     Epoch 00800: MGL: (0.0020 / 0.0020) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0015 / 0.0015) - 1.0 = 0.0008
#     Epoch 01200: MGL: (0.0012 / 0.0012) - 1.0 = 0.0031
#     Epoch 01400: MGL: (0.0010 / 0.0010) - 1.0 = 0.0025
#     Epoch 01600: MGL: (0.0009 / 0.0009) - 1.0 = 0.0001
#     Epoch 01800: MGL: (0.0008 / 0.0008) - 1.0 = 0.0080
#     Epoch 02000: MGL: (0.0007 / 0.0007) - 1.0 = 0.0065
#     Epoch 02200: MGL: (0.0006 / 0.0006) - 1.0 = 0.0046
#     Epoch 02400: MGL: (0.0006 / 0.0005) - 1.0 = 0.0055
#     Epoch 02600: MGL: (0.0005 / 0.0005) - 1.0 = 0.0000
#     Epoch 02800: MGL: (0.0005 / 0.0005) - 1.0 = 0.0495
#     Epoch 03000: MGL: (0.0004 / 0.0004) - 1.0 = 0.0142
#     Epoch 03200: MGL: (0.0004 / 0.0004) - 1.0 = 0.0074
#     Epoch 03400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0042
#     Epoch 03600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0233
#     Epoch 03800: MGL: (0.0004 / 0.0004) - 1.0 = 0.0000
#     Epoch 04000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0230
#     Epoch 04200: MGL: (0.0003 / 0.0003) - 1.0 = 0.0111
#     Epoch 04400: MGL: (0.0003 / 0.0003) - 1.0 = 0.0219
#     Epoch 04600: MGL: (0.0003 / 0.0003) - 1.0 = 0.0112
#     Epoch 04800: MGL: (0.0003 / 0.0003) - 1.0 = 0.0204
#     Epoch 05000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0202
#     Training Loss: 0.00034, MAE: 0.00987
# ============ TRAINING PROCESS: 4 ============
#     Epoch 00200: MGL: (0.0083 / 0.0083) - 1.0 = 0.0031
#     Epoch 00400: MGL: (0.0042 / 0.0042) - 1.0 = 0.0094
#     Epoch 00600: MGL: (0.0027 / 0.0027) - 1.0 = 0.0000
#     Epoch 00800: MGL: (0.0020 / 0.0020) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0015 / 0.0015) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.0012 / 0.0012) - 1.0 = 0.0000
#     Epoch 01400: MGL: (0.0010 / 0.0010) - 1.0 = 0.0007
#     Epoch 01600: MGL: (0.0009 / 0.0009) - 1.0 = 0.0000
#     Epoch 01800: MGL: (0.0008 / 0.0008) - 1.0 = 0.0157
#     Epoch 02000: MGL: (0.0008 / 0.0008) - 1.0 = 0.0000
#     Epoch 02200: MGL: (0.0007 / 0.0007) - 1.0 = 0.0087
#     Epoch 02400: MGL: (0.0007 / 0.0007) - 1.0 = 0.0053
#     Epoch 02600: MGL: (0.0006 / 0.0006) - 1.0 = 0.0000
#     Epoch 02800: MGL: (0.0006 / 0.0006) - 1.0 = 0.0124
#     Epoch 03000: MGL: (0.0005 / 0.0005) - 1.0 = 0.0092
#     Epoch 03200: MGL: (0.0004 / 0.0004) - 1.0 = 0.0169
#     Epoch 03400: MGL: (0.0004 / 0.0004) - 1.0 = 0.0204
#     Epoch 03600: MGL: (0.0004 / 0.0004) - 1.0 = 0.0215
#     Epoch 03800: MGL: (0.0004 / 0.0004) - 1.0 = 0.0456
#     Epoch 04000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0193
#     Epoch 04200: MGL: (0.0003 / 0.0003) - 1.0 = 0.0435
#     Epoch 04400: MGL: (0.0003 / 0.0003) - 1.0 = 0.0273
#     Epoch 04600: MGL: (0.0003 / 0.0003) - 1.0 = 0.0102
#     Epoch 04800: MGL: (0.0003 / 0.0003) - 1.0 = 0.0358
#     Epoch 05000: MGL: (0.0003 / 0.0003) - 1.0 = 0.0189
#     Training Loss: 0.00034, MAE: 0.00922
# ============ TRAINING PROCESS: 5 ============
#     Epoch 00200: MGL: (0.0076 / 0.0076) - 1.0 = 0.0094
#     Epoch 00400: MGL: (0.0042 / 0.0042) - 1.0 = 0.0138
#     Epoch 00600: MGL: (0.0028 / 0.0027) - 1.0 = 0.0040
#     Epoch 00800: MGL: (0.0020 / 0.0020) - 1.0 = 0.0000
#     Epoch 01000: MGL: (0.0017 / 0.0017) - 1.0 = 0.0000
#     Epoch 01200: MGL: (0.0014 / 0.0014) - 1.0 = 0.0003
#     Epoch 01400: MGL: (0.0012 / 0.0012) - 1.0 = 0.0028
#     Epoch 01600: MGL: (0.0010 / 0.0010) - 1.0 = 0.0001
#     Epoch 01800: MGL: (0.0009 / 0.0009) - 1.0 = 0.0056
#     Epoch 02000: MGL: (0.0008 / 0.0008) - 1.0 = 0.0000
#     Epoch 02200: MGL: (0.0007 / 0.0007) - 1.0 = 0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0d49d5199bbe> in <module>()
#       4                  hidden_layer = 1, hidden_cells = [10], batch_size = 1000,
#       5                  GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5,
# ----> 6                  plot = True, plot_name = "ST-T450-h10")
#
# /home/wangkun/simulator/ANN-FC-2.0/istab_pm.pyc in train(train_data, test_data, trans, hidden_layer, hidden_cells, batch_size, epoch, validation_split, validation_data, GL, GL_epoch_strip, min_epoch, train_number, plot, plot_name)
#     444                 validation_split = validation_split, has_val_data = has_val_data, validation_data = validation,
#     445                 GL = GL, GL_epoch_strip = GL_epoch_strip, min_epoch = min_epoch,
# --> 446                 plot = plot, plot_name = plot_name)
#     447
#     448         if loss < loss_opt:
#
# /home/wangkun/simulator/ANN-FC-2.0/istab_pm.pyc in train_model(train_data, test_data, hidden_layer, hidden_cells, batch_size, epoch, GL, GL_epoch_strip, min_epoch, validation_split, has_val_data, validation_data, plot, plot_name)
#     294                 epochs = epoch, validation_data=(feature_val, target_val),
#     295                 verbose=0,
# --> 296                 callbacks = [earlystop, checkpoint])
#     297     else:
#     298         history = model.fit(feature, target, batch_size = batch_size,
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1603           initial_epoch=initial_epoch,
#    1604           steps_per_epoch=steps_per_epoch,
# -> 1605           validation_steps=validation_steps)
#    1606
#    1607   def evaluate(self,
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/engine/training_arrays.pyc in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps)
#     212           ins_batch[i] = ins_batch[i].toarray()
#     213
# --> 214         outs = f(ins_batch)
#     215         if not isinstance(outs, list):
#     216           outs = [outs]
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/backend.pyc in __call__(self, inputs)
#    2937       raise TypeError('`inputs` should be a list or tuple.')
#    2938
# -> 2939     session = get_session()
#    2940     feed_arrays = []
#    2941     array_vals = []
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/backend.pyc in get_session()
#     463   if not _MANUAL_VAR_INIT:
#     464     with session.graph.as_default():
# --> 465       _initialize_variables(session)
#     466   return session
#     467
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/backend.pyc in _initialize_variables(session)
#     708 def _initialize_variables(session):
#     709   """Utility to initialize uninitialized variables on the fly."""
# --> 710   variables = _get_variables(ops.get_default_graph())
#     711   candidate_vars = []
#     712   for v in variables:
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/keras/backend.pyc in _get_variables(graph)
#     702   variables = _GRAPH_VARIABLES.setdefault(graph, weakref.WeakSet())
#     703   for opt in _GRAPH_TF_OPTIMIZERS.get(graph, set()):
# --> 704     variables.update(opt.optimizer.variables())
#     705   return variables
#     706
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/training/optimizer.pyc in variables(self)
#     787     for _, variable_dict in self._slots.items():
#     788       for _, slot_for_variable in variable_dict.items():
# --> 789         if _from_current_graph(slot_for_variable):
#     790           optimizer_variables.append(slot_for_variable)
#     791     # Sort variables by name so that the return is deterministic.
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/training/optimizer.pyc in _from_current_graph(variable)
#     777     def _from_current_graph(variable):
#     778       if variable._in_graph_mode:  # pylint: disable=protected-access
# --> 779         return variable.op.graph is current_graph
#     780       else:
#     781         # No variable.op in eager mode. We don't expect lots of eager graphs,
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/resource_variable_ops.pyc in op(self)
#     701   def op(self):
#     702     """The op for this variable."""
# --> 703     return self._handle.op
#     704
#     705   def eval(self, session=None):
#
# /home/wangkun/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in op(self)
#     335   def op(self):
#     336     """The `Operation` that produces this tensor as an output."""
# --> 337     return self._op
#     338
#     339   @property
#
# KeyboardInterrupt:

# %%
model_20 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [20], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h20")

# %%
model_40 = st.train("improved-STAB-data/PM-simplex-T450-train-simplex-PS-PM.csv",
                 "improved-STAB-data/PM-simplex-T450-test-simplex-PS-PM.csv",
                 validation_data = "improved-STAB-data/PM-simplex-T450-val-simplex-PS-PM.csv",
                 hidden_layer = 1, hidden_cells = [40], batch_size = 1000, 
                 GL = 0.1, GL_epoch_strip = 200, min_epoch = 200, epoch = 5000, trans = None, train_number = 5, 
                 plot = True, plot_name = "ST-T450-h40")

# %%
model = st.ANN_STAB(file_name = 'stab-1010', level = 3)

# %%
model.store_model('stab-1010')
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model.plot('stability-T450-P10')
# Out:
# Correct: 5067
# Wrong: 84
# Uncertain: 0
# Accuracy: 9.836925e-01

# %%
model_10.store_model('stab-10')
model_10.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_10.plot()
# Out:
# Correct: 5049
# Wrong: 102
# Uncertain: 0
# Accuracy: 9.801980e-01

# %%
model_20.store_model('stab-20')
model_20.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_20.plot()
# Out:
# Correct: 5084
# Wrong: 67
# Uncertain: 0
# Accuracy: 9.869928e-01

# %%
model_40.store_model('stab-40')
model_40.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv")
model_40.plot()
# Out:
# Correct: 5037
# Wrong: 114
# Uncertain: 0
# Accuracy: 9.778684e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P10-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 4984
# Wrong: 26
# Uncertain: 141
# Accuracy: 9.949524e-01
# Correct: 4730
# Wrong: 3
# Uncertain: 418
# Accuracy: 9.994176e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv")
model.plot('stability-T450-P50')
# Out:
# Correct: 5114
# Wrong: 37
# Uncertain: 0
# Accuracy: 9.928169e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P50-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5097
# Wrong: 19
# Uncertain: 35
# Accuracy: 9.963114e-01
# Correct: 5047
# Wrong: 4
# Uncertain: 100
# Accuracy: 9.992235e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv")
model.plot('stability-T450-P90')
# Out:
# Correct: 5118
# Wrong: 33
# Uncertain: 0
# Accuracy: 9.935935e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P90-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5105
# Wrong: 21
# Uncertain: 25
# Accuracy: 9.959231e-01
# Correct: 5064
# Wrong: 15
# Uncertain: 72
# Accuracy: 9.970879e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv")
model.plot('stability-T450-P130')
# Out:
# Correct: 5130
# Wrong: 21
# Uncertain: 0
# Accuracy: 9.959231e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P130-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5120
# Wrong: 14
# Uncertain: 17
# Accuracy: 9.972821e-01
# Correct: 5088
# Wrong: 6
# Uncertain: 57
# Accuracy: 9.988352e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv")
model.plot('stability-T450-P170')
# Out:
# Correct: 5136
# Wrong: 15
# Uncertain: 0
# Accuracy: 9.970879e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P170-simplex-STAB-PM.csv", safeguard = 1.5)
model.plot()
# Out:
# Correct: 5131
# Wrong: 8
# Uncertain: 12
# Accuracy: 9.984469e-01
# Correct: 5114
# Wrong: 1
# Uncertain: 36
# Accuracy: 9.998059e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv")
model.plot('stability-T450-P210')
# Out:
# Correct: 5141
# Wrong: 10
# Uncertain: 0
# Accuracy: 9.980586e-01

# %%
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 0.5)
model.stab_test("improved-STAB-data/stability-simplex-T450-P210-simplex-STAB-PM.csv", safeguard = 1.5)

model.plot()
# Out:
# Correct: 5136
# Wrong: 7
# Uncertain: 8
# Accuracy: 9.986410e-01
# Correct: 5127
# Wrong: 2
# Uncertain: 22
# Accuracy: 9.996117e-01

# %%
model_10.store_model('stab-10')
model_10.stab_test("improved-STAB-data/stability-simplex-T450-simplex-STAB-PM.csv")
model_10.plot()
# Out:
# Correct: 5048
# Wrong: 103
# Uncertain: 0
# Accuracy: 9.800039e-01

# %%
model_20.store_model('stab-20')
model_20.stab_test("improved-STAB-data/stability-simplex-T450-simplex-STAB-PM.csv")
model_20.plot()
# Out:
# Correct: 5060
# Wrong: 91
# Uncertain: 0
# Accuracy: 9.823335e-01
